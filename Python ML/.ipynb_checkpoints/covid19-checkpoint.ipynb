# %%
import pandas as pd

data_frame = pd.read_csv("data.csv")
data_frame.shape
# Out:
# (29045, 20)

# %%
data_frame.describe()
# Out:
#             Entry_ID     Num Cases  Source_3  Nationality  \
# count   29045.000000  29044.000000       0.0          0.0
# mean   182128.782579     11.463331       NaN          NaN
# std      8386.588279    155.041428       NaN          NaN
# min    167605.000000  -8348.000000       NaN          NaN
# 25%    174866.000000      1.000000       NaN          NaN
# 50%    182129.000000      1.000000       NaN          NaN
# 75%    189391.000000      1.000000       NaN          NaN
# max    196658.000000   8348.000000       NaN          NaN
#
#        Type of transmission  Status Change Date  Patient Number
# count                   0.0                 0.0             0.0
# mean                    NaN                 NaN             NaN
# std                     NaN                 NaN             NaN
# min                     NaN                 NaN             NaN
# 25%                     NaN                 NaN             NaN
# ...

# %%
data_frame.values
# Out:
# array([[167605, nan, '18/07/2020', ..., nan, nan, nan],
#        [167606, nan, '18/07/2020', ..., nan, nan, nan],
#        [167607, nan, '18/07/2020', ..., nan, nan, nan],
#        ...,
#        [196656, nan, '29/05/2020', ..., nan, nan, nan],
#        [196657, nan, '29/05/2020', ..., nan, nan, nan],
#        [196658, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
print(data_frame)
# Out:
#        Entry_ID State Patient Number Date Announced Age Bracket Gender  \
# 0        167605                  NaN     18/07/2020         NaN    NaN
# 1        167606                  NaN     18/07/2020         NaN    NaN
# 2        167607                  NaN     18/07/2020         NaN    NaN
# 3        167608                  NaN     18/07/2020         NaN    NaN
# 4        167609                  NaN     18/07/2020         NaN    NaN
# 5        167610                  NaN     18/07/2020         NaN    NaN
# 6        167611                  NaN     18/07/2020         NaN    NaN
# 7        167612                  NaN     18/07/2020         NaN    NaN
# 8        167613                  NaN     18/07/2020         NaN    NaN
# 9        167614                  NaN     18/07/2020         NaN    NaN
# 10       167615                  NaN     18/07/2020         NaN    NaN
# 11       167616                  NaN     18/07/2020         NaN    NaN
# ...

# %%
genders = data_frame['Gender'] 
genders.head(10)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: Gender, dtype: object

# %%
data_frame[data_frame['Gender']=="M"].shape
# Out:
# (10361, 20)

# %%
data_frame[data_frame['Gender']=="F"].shape
# Out:
# (6184, 20)

# %%
data_frame[data_frame['Gender']=="F"].head()
# Out:
#      Entry_ID State Patient Number Date Announced Age Bracket Gender  \
# 28     167633                  NaN     18/07/2020          48      F
# 334    167939                  NaN     18/07/2020          55      F
# 335    167940                  NaN     18/07/2020          11      F
# 341    167946                  NaN     18/07/2020          45      F
# 344    167949                  NaN     18/07/2020          55      F
#
#     Detected City Detected District Detected State State code  Num Cases  \
# 28            NaN          Gajapati         Odisha         OR        1.0
# 334    R/o.Sec.25        Chandigarh     Chandigarh         CH        1.0
# 335    R/o.Sec.25        Chandigarh     Chandigarh         CH        1.0
# 341    R/o.Sec.29        Chandigarh     Chandigarh         CH        1.0
# 344    R/o.Sec.29        Chandigarh     Chandigarh         CH        1.0
#
#     Current Status Contracted from which Patient (Suspected)  \
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['Age Bracket', 'Gender', 'Current Status', 'Detected State','Entry_ID'])
print(df1)
# Out:
#       Age Bracket Gender Current Status    Detected State  Entry_ID
# 0             NaN    NaN   Hospitalized  State Unassigned    167605
# 1             NaN    NaN   Hospitalized            Odisha    167606
# 2             NaN    NaN   Hospitalized            Odisha    167607
# 3             NaN    NaN   Hospitalized            Odisha    167608
# 4             NaN    NaN   Hospitalized            Odisha    167609
# 5             NaN    NaN   Hospitalized            Odisha    167610
# 6             NaN    NaN   Hospitalized            Odisha    167611
# 7             NaN    NaN   Hospitalized            Odisha    167612
# 8             NaN    NaN   Hospitalized            Odisha    167613
# 9             NaN    NaN   Hospitalized            Odisha    167614
# 10            NaN    NaN   Hospitalized            Odisha    167615
# 11            NaN    NaN   Hospitalized            Odisha    167616
# 12            NaN    NaN   Hospitalized            Odisha    167617
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = df1.dropna()
df1.shape
# Out:
# (29045, 5)

# %%
df2.shape
# Out:
# (16546, 5)

# %%
print(df1.shape[0] - df2.shape[0])
# Out:
# 12499

# %%
df2.sort_values('Detected State')
# Out:
#       Age Bracket Gender Current Status Detected State  Entry_ID
# 7507           62      M       Deceased          Assam    175112
# 19219          45      M       Deceased          Assam    186826
# 25526          44      F       Deceased          Assam    193134
# 714            61      M       Deceased          Assam    168319
# 7508           78      F       Deceased          Assam    175113
# 7509           46      M       Deceased          Assam    175114
# 715            62      M       Deceased          Assam    168320
# 25521          63      F       Deceased          Assam    193129
# 25522          51      F       Deceased          Assam    193130
# 25523          74      F       Deceased          Assam    193131
# 25524          65      M       Deceased          Assam    193132
# 25525          67      M       Deceased          Assam    193133
# 7510           74      M       Deceased          Assam    175115
# ...

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Age Bracket', y='Entry_ID', data=df2)
graph

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

p = figure (title="test", x_axis_label='x', y_axis_label='y', plot_width=700, plot_height=700, tools=[hover])
p.circle('Entry_ID', 'Age Bracket', size = 10, source=df2)
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-12d41c4b06a4> in <module>
#       2 from bokeh.models import HoverTool
#       3
# ----> 4 p = figure (title="test", x_axis_label='x', y_axis_label='y', plot_width=700, plot_height=700, tools=[hover])
#       5 p.circle('Entry_ID', 'Age Bracket', size = 10, source=df2)
#       6 show(p)
#
# NameError: name 'hover' is not defined
